# %%
import pandas as pd
data=pd.read_csv('train.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
len(data.columns)
# Out:
# 81

# %%
 len(data)
# Out:
# 1460

# %%
test=data.sample(260)

# %%
train=data.drop(test.index)

# %%
len(test)
# Out:
# 260

# %%
len(train)
# Out:
# 1200

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5            Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 4        12   2008        WD         Normal     250000
# 5        10   2009        WD         Normal     143000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1200 rows x 81 columns]

# %%
feature=['LotArea','TotRmsAbvGrd','PoolArea','YearBuilt']
target=['SalePrice']

# %%
data[target]
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 1 columns]

# %%
#ML Algorithem
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=200)
model=rf.fit(train[feature],train[target])
# Out:
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model=l.fit(train[feature],train[target])

# %%
pred_value=model.predict(test[feature])

# %%
test['Pred_value']=pred_value

# %%
test[['LotArea','SalePrice','Pred_value']]
# Out:
#       LotArea  SalePrice     Pred_value
# 1377    10998     117000  132708.252232
# 859     11029     250000  229558.159850
# 818      8816     155000  166637.356802
# 1334     2368     125000  177008.718298
# 1289    11065     281000  255542.664818
# ...       ...        ...            ...
# 883      6204     118500  174218.477656
# 1353    14720     410000  268437.844806
# 237      9453     194500  215943.006114
# 1278     9473     237000  227117.089915
# 1341    13695     155000  213461.330984
#
# [260 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test['SalePrice'],pred_value)
# Out:
# 40259.83457796568

# %%
list(map(int,pred_value))
# Out:
# [132708,
#  229558,
#  166637,
#  177008,
#  255542,
#  128142,
#  310370,
#  115829,
#  129828,
#  219035,
#  137653,
#  172579,
#  240695,
#  252199,
#  144666,
#  182032,
#  171930,
#  252495,
#  146226,
#  216405,
#  135671,
#  140125,
#  159832,
#  127526,
#  86836,
#  102769,
#  124751,
#  149177,
#  234954,
#  208736,
#  277661,
#  436085,
#  119142,
#  193451,
#  243329,
#  150814,
#  206836,
#  122097,
#  222648,
#  139574,
#  127889,
#  90426,
#  393255,
#  153939,
#  141601,
#  151553,
#  104389,
#  103707,
#  227513,
#  178725,
#  127848,
#  111742,
#  196248,
#  173504,
#  147215,
#  137010,
#  151695,
#  100945,
#  101100,
#  206521,
#  134997,
#  208007,
#  134796,
#  276325,
#  207437,
#  229437,
#  100709,
#  199919,
#  246136,
#  119499,
#  294655,
#  172127,
#  117125,
#  241644,
#  127636,
#  224604,
#  199521,
#  226675,
#  188440,
#  327118,
#  193400,
#  231319,
#  194967,
#  93697,
#  213266,
#  226382,
#  250023,
#  144367,
#  325038,
#  227810,
#  113391,
#  135607,
#  124043,
#  233394,
#  182118,
#  144720,
#  138503,
#  102496,
#  257920,
#  105758,
#  166367,
#  138285,
#  101466,
#  160147,
#  204906,
#  148204,
#  73088,
#  154953,
#  199946,
#  83351,
#  247121,
#  96969,
#  163352,
#  222645,
#  64805,
#  157542,
#  91241,
#  172625,
#  121293,
#  148042,
#  145033,
#  249824,
#  238930,
#  197404,
#  155827,
#  164814,
#  235220,
#  278663,
#  251178,
#  117680,
#  225908,
#  105698,
#  178010,
#  156001,
#  205672,
#  229592,
#  170271,
#  148798,
#  152521,
#  239288,
#  288103,
#  300174,
#  156707,
#  98195,
#  228816,
#  185567,
#  109736,
#  215380,
#  298378,
#  212142,
#  187953,
#  179372,
#  281076,
#  192585,
#  143095,
#  156559,
#  232847,
#  110832,
#  116852,
#  118289,
#  208185,
#  83619,
#  152830,
#  230249,
#  204689,
#  130943,
#  128252,
#  219337,
#  204925,
#  159525,
#  138993,
#  195109,
#  156533,
#  211342,
#  157551,
#  237117,
#  262695,
#  170283,
#  105918,
#  173817,
#  325363,
#  152087,
#  152567,
#  175448,
#  179880,
#  247538,
#  158859,
#  220717,
#  268809,
#  295452,
#  258759,
#  265460,
#  95456,
#  153887,
#  138066,
#  278832,
#  180467,
#  198291,
#  141956,
#  87618,
#  261399,
#  159132,
#  102668,
#  123222,
#  137337,
#  297404,
#  216058,
#  221097,
#  103797,
#  182087,
#  173558,
#  91206,
#  152934,
#  142404,
#  235885,
#  310210,
#  240017,
#  153128,
#  219871,
#  227946,
#  192438,
#  151426,
#  272014,
#  172696,
#  202408,
#  222349,
#  48797,
#  188859,
#  213047,
#  210716,
#  235472,
#  230114,
#  248090,
#  144506,
#  157303,
#  208957,
#  174905,
#  170784,
#  150974,
#  303436,
#  165538,
#  256038,
#  108501,
#  260641,
#  186785,
#  242713,
#  163668,
#  177658,
#  241904,
#  219892,
#  181098,
#  161790,
#  241865,
#  106249,
#  210268,
#  174218,
#  268437,
#  215943,
#  227117,
#  213461]
