# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[23,53,56,88,12,65,49]

# %%
plt.plot(x,y,'g*--',markersize=12,alpha=0.7)

# %%
plt.plot(x,y,color='red',marker='D',linestyle='')
