# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[23,53,56,88,12,65,49]

# %%
plt.xlabel('Day')
plt.ylabel('Temparature')
plt.title('Wether')
plt.plot(x,y,color='red',linewidth=2,linestyle='dotted')
